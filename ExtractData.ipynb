# %%
import matplotlib.pyplot as plt
import cv2
import easyocr
from pylab import rcParams
from IPython.display import Image
rcParams['figure.figsize'] = 8, 16

# %%
reader = easyocr.Reader(['en'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
Image("Images\ImagesFromFrontEnd\Image.jpg")

# %%
output = reader.readtext('Images\ImagesFromFrontEnd\Image.jpg')

# %%
output
# Out:
# [([[1888, 289], [2254, 289], [2254, 436], [1888, 436]],
#   'Devis',
#   0.9995512075692995),
#  ([[269, 548], [589, 548], [589, 657], [269, 657]],
#   'Details',
#   0.8407783279840629),
#  ([[271, 764], [463, 764], [463, 856], [271, 856]], 'Nom', 0.9999922915462542),
#  ([[508, 763], [734, 763], [734, 866], [508, 866]],
#   'najeh',
#   0.9999924296904882),
#  ([[2832, 757], [3865, 757], [3865, 866], [2832, 866]],
#   'Date: 28/08/2022, 16.56.09',
#   0.818422486773875),
#  ([[263, 850], [922, 850], [922, 963], [263, 963]],
#   'Societe : adiddas',
#   0.8350032342751819),
#  ([[3275, 857], [3668, 857], [3668, 961], [3275, 961]],
#   "N'Facture",
#   0.8540850983981838),
#  ([[3702, 860], [3862, 860], [3862, 952], [3702, 952]],
#   '362',
#   0.9999986923153217),
#  ([[273, 957], [599, 957], [599, 1060], [273, 1060]],
#   'Adresse',
#   0.9999974768138993),
#  ([[631, 955], [848, 955], [848, 1054], [631, 1054]],
#   'kebili',
#   0.9999785378062361),
#  ([[267, 1057], [737, 1057], [737, 1148], [267, 1148]],
#   'Code Postal',
#   0.7656531853422639),
#  ([[796, 1057], [1007, 1057], [1007, 1148], [796, 1148]],
#   '4200',
#   0.764413245192292),
#  ([[268, 1149], [498, 1149], [498, 1251], [268, 1251]],
#   'Email',
#   0.9998851118286726),
#  ([[530, 1151], [1068, 1151], [1068, 1265], [530, 1265]],
#   'gh@gmil.com',
#   0.618601075709268),
#  ([[262, 1244], [682, 1244], [682, 1367], [262, 1367]],
#   'Telephone',
#   0.8261535642735495),
#  ([[713, 1248], [1108, 1248], [1108, 1346], [713, 1346]], '20258258', 1.0),
#  ([[269, 1457], [589, 1457], [589, 1566], [269, 1566]],
#   'Details',
#   0.7742679636737188),
#  ([[302, 1691], [592, 1691], [592, 1789], [302, 1789]],
#   'Produit',
#   0.7407305081628247),
#  ([[2788, 1696], [3072, 1696], [3072, 1783], [2788, 1783]],
#   'PrixHT',
#   0.9995866520636412),
#  ([[3114, 1684], [3454, 1684], [3454, 1792], [3114, 1792]],
#   'Quantite',
#   0.8110955989232995),
#  ([[3496, 1692], [3825, 1692], [3825, 1783], [3496, 1783]],
#   'Total.HT',
#   0.9317296090055938),
#  ([[308, 1843], [413, 1843], [413, 1930], [308, 1930]],
#   'pc',
#   0.4582763107140303),
#  ([[2789, 1834], [2897, 1834], [2897, 1915], [2789, 1915]],
#   '12',
#   0.9999987355947788),
#  ([[3120, 1836], [3174, 1836], [3174, 1908], [3120, 1908]],
#   '2',
#   0.9999817610618642),
#  ([[3496, 1829], [3720, 1829], [3720, 1916], [3496, 1916]],
#   '24.00',
#   0.9994012097410881),
#  ([[303, 1957], [637, 1957], [637, 2048], [303, 2048]],
#   'Total.HT',
#   0.8979257226166495),
#  ([[3501, 1961], [3720, 1961], [3720, 2048], [3501, 2048]],
#   '24.00',
#   0.9997956525819446),
#  ([[3494, 2179], [3868, 2179], [3868, 2288], [3494, 2288]],
#   'Signature',
#   0.999986052464489),
#  ([[264, 2572], [1208, 2572], [1208, 2692], [264, 2692]],
#   'Termes et conditions',
#   0.7770499419785909),
#  ([[361, 2791], [2982, 2791], [2982, 2902], [361, 2902]],
#   'La commande peut etre retournee dans un delai maximum de 10 jours',
#   0.6346454784515765),
#  ([[354, 2869], [1553, 2869], [1553, 3007], [354, 3007]],
#   'Facture generee par le systeme:',
#   0.5875909064356203)]

# %%
cord = output[-9][0]

# %%
x_min, y_min = [int(min(idx)) for idx in zip(*cord)]

# %%
x_max, y_max = [int(max(idx)) for idx in zip(*cord)]

# %%
image = cv2.imread('Images\ImagesFromFrontEnd\Image.jpg')
cv2.rectangle(image,(x_min,y_min),(x_max,y_max),(0,0,255),2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
